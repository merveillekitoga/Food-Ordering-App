# %% [markdown]
# <a href="https://colab.research.google.com/github/merveillekitoga/Food-Ordering-App/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits= ["banane", "pomme", "orange"]
print(fruits[1])
# Out:
# pomme

# %%
for fruit in fruits:
    print(fruit)
# Out:
# banane
# pomme
# orange

# %%
def direBonjour(nom):
  print("Bonjour "+ nom)

direBonjour("Mussambo")
# Out:
# Bonjour Mussambo

# %%
def addition(a,b):
  return a+b

resultat= addition(2,8)
print(resultat)
# Out:
# 10
